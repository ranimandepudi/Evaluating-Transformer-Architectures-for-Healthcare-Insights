# %%
pip install transformers torch pandas sklearn datasets
# Out:
# Requirement already satisfied: transformers in /Users/ranichowdarymandepudi/anaconda3/lib/python3.11/site-packages (4.29.2)
# Requirement already satisfied: torch in /Users/ranichowdarymandepudi/anaconda3/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: pandas in /Users/ranichowdarymandepudi/anaconda3/lib/python3.11/site-packages (1.5.3)
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments, TrainerCallback
from datasets import Dataset
from sklearn.preprocessing import LabelEncoder
import torch
import os
import joblib
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('drugsComTrain_raw.tsv', sep='\t')
len(df)
# Out:
# 161297

# %%
# Load and prepare data
df = pd.read_csv('drugsComTrain_raw.tsv', sep='\t', nrows = 150000)
df = df[df['condition'].isin(['Birth Control', 'Depression', 'High Blood Pressure', 'Diabetes, Type 2'])]
df = df.dropna(subset=['review'])  # Ensuring no null reviews

# Preprocess text data
def preprocess_text(text):
    return text.str.replace('<[^<]+?>', '')  # Remove HTML tags

df['cleaned_text'] = preprocess_text(df['review'])

# Prepare labels
label_encoder = LabelEncoder()
df['encoded_labels'] = label_encoder.fit_transform(df['condition'])
labels = df['encoded_labels']

# Split data first
X_train, X_test, y_train, y_test = train_test_split(df['cleaned_text'], labels, test_size=0.2, random_state=42)

# Tokenization
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
train_encodings = tokenizer(list(X_train), truncation=True, padding=True, max_length=256)
test_encodings = tokenizer(list(X_test), truncation=True, padding=True, max_length=256)

# Create torch datasets
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels.iloc[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = CustomDataset(train_encodings, y_train)
test_dataset = CustomDataset(test_encodings, y_test)

# Model setup
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=len(label_encoder.classes_))

# Training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64,
    warmup_steps=500,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    logging_dir='./logs',
    logging_steps=10,
)
# Prepare to capture training and validation loss
training_loss_set = []
validation_loss_set = []

# Callback to Hugging Face Trainer to capture training loss after each logging step
class LossLoggingCallback(TrainerCallback):
    def on_log(self, args, state, control, logs=None, **kwargs):
        if 'loss' in logs:
            training_loss_set.append(logs['loss'])
        if 'eval_loss' in logs:
            validation_loss_set.append(logs['eval_loss'])
# Define the compute_metrics function
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    acc = accuracy_score(labels, preds)
    return {'accuracy': acc}

# Initialize Trainer with compute_metrics
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()
print(f"Test Loss: {results['eval_loss']}, Test Accuracy: {results['eval_accuracy']}")
# Out:
# /var/folders/3z/kmvcrzsd3fsg9kc9r3kyhyww0000gn/T/ipykernel_78696/2886871454.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   return text.str.replace('<[^<]+?>', '')  # Remove HTML tags
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.bias', 'classifier.weight', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ranichowdarymandepudi/anaconda3/lib/python3.11/site-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/9950 [00:00<?, ?it/s]
# {'loss': 1.4026, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.01}
# {'loss': 1.3789, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.01}
# {'loss': 1.321, 'learning_rate': 3e-06, 'epoch': 0.02}
# {'loss': 1.2319, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.02}
# {'loss': 1.1078, 'learning_rate': 5e-06, 'epoch': 0.03}
# {'loss': 0.963, 'learning_rate': 6e-06, 'epoch': 0.03}
# {'loss': 0.9155, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.04}
# {'loss': 0.8322, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.04}
# {'loss': 0.8445, 'learning_rate': 9e-06, 'epoch': 0.05}
# {'loss': 0.7102, 'learning_rate': 1e-05, 'epoch': 0.05}
# {'loss': 0.6545, 'learning_rate': 1.1000000000000001e-05, 'epoch': 0.06}
# {'loss': 0.5757, 'learning_rate': 1.2e-05, 'epoch': 0.06}
# {'loss': 0.5467, 'learning_rate': 1.3000000000000001e-05, 'epoch': 0.07}
# {'loss': 0.4704, 'learning_rate': 1.4000000000000001e-05, 'epoch': 0.07}
# {'loss': 0.5061, 'learning_rate': 1.5e-05, 'epoch': 0.08}
# {'loss': 0.4095, 'learning_rate': 1.6000000000000003e-05, 'epoch': 0.08}
# {'loss': 0.36, 'learning_rate': 1.7000000000000003e-05, 'epoch': 0.09}
# {'loss': 0.3976, 'learning_rate': 1.8e-05, 'epoch': 0.09}
# {'loss': 0.304, 'learning_rate': 1.9e-05, 'epoch': 0.1}
# {'loss': 0.2807, 'learning_rate': 2e-05, 'epoch': 0.1}
# {'loss': 0.2956, 'learning_rate': 2.1e-05, 'epoch': 0.11}
# {'loss': 0.2356, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.11}
# {'loss': 0.3494, 'learning_rate': 2.3000000000000003e-05, 'epoch': 0.12}
# {'loss': 0.2529, 'learning_rate': 2.4e-05, 'epoch': 0.12}
# {'loss': 0.3046, 'learning_rate': 2.5e-05, 'epoch': 0.13}
# {'loss': 0.1937, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.13}
# {'loss': 0.1612, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.14}
# {'loss': 0.1725, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.14}
# {'loss': 0.1126, 'learning_rate': 2.9e-05, 'epoch': 0.15}
# {'loss': 0.2433, 'learning_rate': 3e-05, 'epoch': 0.15}
# {'loss': 0.1157, 'learning_rate': 3.1e-05, 'epoch': 0.16}
# {'loss': 0.1768, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.16}
# {'loss': 0.1011, 'learning_rate': 3.3e-05, 'epoch': 0.17}
# {'loss': 0.1124, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.17}
# {'loss': 0.1366, 'learning_rate': 3.5e-05, 'epoch': 0.18}
# {'loss': 0.2081, 'learning_rate': 3.6e-05, 'epoch': 0.18}
# {'loss': 0.1523, 'learning_rate': 3.7e-05, 'epoch': 0.19}
# {'loss': 0.1147, 'learning_rate': 3.8e-05, 'epoch': 0.19}
# {'loss': 0.157, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.2}
# {'loss': 0.1176, 'learning_rate': 4e-05, 'epoch': 0.2}
# {'loss': 0.1841, 'learning_rate': 4.1e-05, 'epoch': 0.21}
# {'loss': 0.2079, 'learning_rate': 4.2e-05, 'epoch': 0.21}
# {'loss': 0.1005, 'learning_rate': 4.3e-05, 'epoch': 0.22}
# {'loss': 0.1044, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.22}
# {'loss': 0.1315, 'learning_rate': 4.5e-05, 'epoch': 0.23}
# {'loss': 0.142, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.23}
# {'loss': 0.3019, 'learning_rate': 4.7e-05, 'epoch': 0.24}
# {'loss': 0.1565, 'learning_rate': 4.8e-05, 'epoch': 0.24}
# {'loss': 0.1521, 'learning_rate': 4.9e-05, 'epoch': 0.25}
# {'loss': 0.1722, 'learning_rate': 5e-05, 'epoch': 0.25}
# {'loss': 0.1543, 'learning_rate': 4.9947089947089946e-05, 'epoch': 0.26}
# {'loss': 0.2005, 'learning_rate': 4.9894179894179895e-05, 'epoch': 0.26}
# {'loss': 0.1143, 'learning_rate': 4.9841269841269845e-05, 'epoch': 0.27}
# {'loss': 0.1106, 'learning_rate': 4.978835978835979e-05, 'epoch': 0.27}
# {'loss': 0.1104, 'learning_rate': 4.973544973544973e-05, 'epoch': 0.28}
# {'loss': 0.2246, 'learning_rate': 4.968253968253969e-05, 'epoch': 0.28}
# {'loss': 0.1339, 'learning_rate': 4.962962962962963e-05, 'epoch': 0.29}
# {'loss': 0.1197, 'learning_rate': 4.9576719576719575e-05, 'epoch': 0.29}
# {'loss': 0.2443, 'learning_rate': 4.9523809523809525e-05, 'epoch': 0.3}
# {'loss': 0.1089, 'learning_rate': 4.9470899470899475e-05, 'epoch': 0.3}
# {'loss': 0.0331, 'learning_rate': 4.941798941798942e-05, 'epoch': 0.31}
# {'loss': 0.1051, 'learning_rate': 4.936507936507937e-05, 'epoch': 0.31}
# {'loss': 0.1975, 'learning_rate': 4.931216931216932e-05, 'epoch': 0.32}
# {'loss': 0.0405, 'learning_rate': 4.925925925925926e-05, 'epoch': 0.32}
# {'loss': 0.1233, 'learning_rate': 4.9206349206349204e-05, 'epoch': 0.33}
# {'loss': 0.1079, 'learning_rate': 4.9153439153439154e-05, 'epoch': 0.33}
# {'loss': 0.1328, 'learning_rate': 4.9100529100529104e-05, 'epoch': 0.34}
# {'loss': 0.053, 'learning_rate': 4.904761904761905e-05, 'epoch': 0.34}
# {'loss': 0.0899, 'learning_rate': 4.8994708994709e-05, 'epoch': 0.35}
# {'loss': 0.1175, 'learning_rate': 4.894179894179895e-05, 'epoch': 0.35}
# {'loss': 0.0822, 'learning_rate': 4.888888888888889e-05, 'epoch': 0.36}
# {'loss': 0.1131, 'learning_rate': 4.883597883597884e-05, 'epoch': 0.36}
# {'loss': 0.0975, 'learning_rate': 4.878306878306878e-05, 'epoch': 0.37}
# {'loss': 0.1705, 'learning_rate': 4.873015873015873e-05, 'epoch': 0.37}
# {'loss': 0.1617, 'learning_rate': 4.8677248677248676e-05, 'epoch': 0.38}
# {'loss': 0.0962, 'learning_rate': 4.8624338624338626e-05, 'epoch': 0.38}
# {'loss': 0.153, 'learning_rate': 4.8571428571428576e-05, 'epoch': 0.39}
# {'loss': 0.1105, 'learning_rate': 4.851851851851852e-05, 'epoch': 0.39}
# {'loss': 0.0351, 'learning_rate': 4.846560846560847e-05, 'epoch': 0.4}
# {'loss': 0.1715, 'learning_rate': 4.841269841269841e-05, 'epoch': 0.4}
# {'loss': 0.0958, 'learning_rate': 4.835978835978836e-05, 'epoch': 0.41}
# {'loss': 0.0644, 'learning_rate': 4.830687830687831e-05, 'epoch': 0.41}
# {'loss': 0.1382, 'learning_rate': 4.8253968253968255e-05, 'epoch': 0.42}
# {'loss': 0.1459, 'learning_rate': 4.8201058201058205e-05, 'epoch': 0.42}
# {'loss': 0.0677, 'learning_rate': 4.814814814814815e-05, 'epoch': 0.43}
# {'loss': 0.1699, 'learning_rate': 4.80952380952381e-05, 'epoch': 0.43}
# {'loss': 0.0803, 'learning_rate': 4.804232804232804e-05, 'epoch': 0.44}
# {'loss': 0.1304, 'learning_rate': 4.798941798941799e-05, 'epoch': 0.44}
# {'loss': 0.1478, 'learning_rate': 4.793650793650794e-05, 'epoch': 0.45}
# {'loss': 0.1207, 'learning_rate': 4.7883597883597884e-05, 'epoch': 0.45}
# {'loss': 0.1068, 'learning_rate': 4.7830687830687834e-05, 'epoch': 0.46}
# {'loss': 0.1373, 'learning_rate': 4.7777777777777784e-05, 'epoch': 0.46}
# {'loss': 0.101, 'learning_rate': 4.772486772486773e-05, 'epoch': 0.47}
# {'loss': 0.1028, 'learning_rate': 4.767195767195767e-05, 'epoch': 0.47}
# {'loss': 0.0951, 'learning_rate': 4.761904761904762e-05, 'epoch': 0.48}
# {'loss': 0.178, 'learning_rate': 4.756613756613757e-05, 'epoch': 0.48}
# {'loss': 0.0743, 'learning_rate': 4.7513227513227513e-05, 'epoch': 0.49}
# {'loss': 0.0581, 'learning_rate': 4.746031746031746e-05, 'epoch': 0.49}
# {'loss': 0.0547, 'learning_rate': 4.740740740740741e-05, 'epoch': 0.5}
# {'loss': 0.0707, 'learning_rate': 4.7354497354497356e-05, 'epoch': 0.5}
# {'loss': 0.2, 'learning_rate': 4.73015873015873e-05, 'epoch': 0.51}
# {'loss': 0.1524, 'learning_rate': 4.7248677248677256e-05, 'epoch': 0.51}
# {'loss': 0.1026, 'learning_rate': 4.71957671957672e-05, 'epoch': 0.52}
# {'loss': 0.095, 'learning_rate': 4.714285714285714e-05, 'epoch': 0.52}
# {'loss': 0.1122, 'learning_rate': 4.708994708994709e-05, 'epoch': 0.53}
# {'loss': 0.1253, 'learning_rate': 4.703703703703704e-05, 'epoch': 0.53}
# {'loss': 0.1645, 'learning_rate': 4.6984126984126986e-05, 'epoch': 0.54}
# {'loss': 0.1664, 'learning_rate': 4.693121693121693e-05, 'epoch': 0.54}
# {'loss': 0.0833, 'learning_rate': 4.6878306878306885e-05, 'epoch': 0.55}
# {'loss': 0.0548, 'learning_rate': 4.682539682539683e-05, 'epoch': 0.55}
# {'loss': 0.0731, 'learning_rate': 4.677248677248677e-05, 'epoch': 0.56}
# {'loss': 0.1085, 'learning_rate': 4.671957671957672e-05, 'epoch': 0.56}
# {'loss': 0.252, 'learning_rate': 4.666666666666667e-05, 'epoch': 0.57}
# {'loss': 0.0528, 'learning_rate': 4.6613756613756615e-05, 'epoch': 0.57}
# {'loss': 0.1122, 'learning_rate': 4.656084656084656e-05, 'epoch': 0.58}
# {'loss': 0.1076, 'learning_rate': 4.6507936507936515e-05, 'epoch': 0.58}
# {'loss': 0.1118, 'learning_rate': 4.645502645502646e-05, 'epoch': 0.59}
# {'loss': 0.0677, 'learning_rate': 4.64021164021164e-05, 'epoch': 0.59}
# {'loss': 0.0396, 'learning_rate': 4.634920634920635e-05, 'epoch': 0.6}
# {'loss': 0.1029, 'learning_rate': 4.62962962962963e-05, 'epoch': 0.6}
# {'loss': 0.1175, 'learning_rate': 4.6243386243386244e-05, 'epoch': 0.61}
# {'loss': 0.188, 'learning_rate': 4.6190476190476194e-05, 'epoch': 0.61}
# {'loss': 0.1389, 'learning_rate': 4.6137566137566144e-05, 'epoch': 0.62}
# {'loss': 0.0736, 'learning_rate': 4.608465608465609e-05, 'epoch': 0.62}
# {'loss': 0.081, 'learning_rate': 4.603174603174603e-05, 'epoch': 0.63}
# {'loss': 0.094, 'learning_rate': 4.597883597883598e-05, 'epoch': 0.63}
# {'loss': 0.0719, 'learning_rate': 4.592592592592593e-05, 'epoch': 0.64}
# {'loss': 0.0709, 'learning_rate': 4.587301587301587e-05, 'epoch': 0.64}
# {'loss': 0.1065, 'learning_rate': 4.582010582010582e-05, 'epoch': 0.65}
# {'loss': 0.0672, 'learning_rate': 4.576719576719577e-05, 'epoch': 0.65}
# {'loss': 0.2103, 'learning_rate': 4.5714285714285716e-05, 'epoch': 0.66}
# {'loss': 0.1247, 'learning_rate': 4.5661375661375666e-05, 'epoch': 0.66}
# {'loss': 0.0258, 'learning_rate': 4.560846560846561e-05, 'epoch': 0.67}
# {'loss': 0.1336, 'learning_rate': 4.555555555555556e-05, 'epoch': 0.67}
# {'loss': 0.1609, 'learning_rate': 4.55026455026455e-05, 'epoch': 0.68}
# {'loss': 0.0767, 'learning_rate': 4.544973544973545e-05, 'epoch': 0.68}
# {'loss': 0.1919, 'learning_rate': 4.5396825396825395e-05, 'epoch': 0.69}
# {'loss': 0.1231, 'learning_rate': 4.5343915343915345e-05, 'epoch': 0.69}
# {'loss': 0.1253, 'learning_rate': 4.5291005291005295e-05, 'epoch': 0.7}
# {'loss': 0.0476, 'learning_rate': 4.523809523809524e-05, 'epoch': 0.7}
# {'loss': 0.1629, 'learning_rate': 4.518518518518519e-05, 'epoch': 0.71}
# {'loss': 0.0647, 'learning_rate': 4.513227513227514e-05, 'epoch': 0.71}
# {'loss': 0.0826, 'learning_rate': 4.507936507936508e-05, 'epoch': 0.72}
# {'loss': 0.0492, 'learning_rate': 4.5026455026455024e-05, 'epoch': 0.72}
# {'loss': 0.09, 'learning_rate': 4.4973544973544974e-05, 'epoch': 0.73}
# {'loss': 0.0551, 'learning_rate': 4.4920634920634924e-05, 'epoch': 0.73}
# {'loss': 0.0726, 'learning_rate': 4.486772486772487e-05, 'epoch': 0.74}
# {'loss': 0.0917, 'learning_rate': 4.481481481481482e-05, 'epoch': 0.74}
# {'loss': 0.1495, 'learning_rate': 4.476190476190477e-05, 'epoch': 0.75}
# {'loss': 0.1626, 'learning_rate': 4.470899470899471e-05, 'epoch': 0.75}
# {'loss': 0.0838, 'learning_rate': 4.4656084656084654e-05, 'epoch': 0.76}
# {'loss': 0.072, 'learning_rate': 4.460317460317461e-05, 'epoch': 0.76}
# {'loss': 0.0492, 'learning_rate': 4.4550264550264553e-05, 'epoch': 0.77}
# {'loss': 0.1652, 'learning_rate': 4.44973544973545e-05, 'epoch': 0.77}
# {'loss': 0.0811, 'learning_rate': 4.4444444444444447e-05, 'epoch': 0.78}
# {'loss': 0.0131, 'learning_rate': 4.4391534391534397e-05, 'epoch': 0.78}
# {'loss': 0.1711, 'learning_rate': 4.433862433862434e-05, 'epoch': 0.79}
# {'loss': 0.1473, 'learning_rate': 4.428571428571428e-05, 'epoch': 0.79}
# {'loss': 0.0823, 'learning_rate': 4.423280423280424e-05, 'epoch': 0.8}
# {'loss': 0.1375, 'learning_rate': 4.417989417989418e-05, 'epoch': 0.8}
# {'loss': 0.0388, 'learning_rate': 4.4126984126984126e-05, 'epoch': 0.81}
# {'loss': 0.145, 'learning_rate': 4.4074074074074076e-05, 'epoch': 0.81}
# {'loss': 0.0603, 'learning_rate': 4.4021164021164026e-05, 'epoch': 0.82}
# {'loss': 0.1587, 'learning_rate': 4.396825396825397e-05, 'epoch': 0.82}
# {'loss': 0.0342, 'learning_rate': 4.391534391534391e-05, 'epoch': 0.83}
# {'loss': 0.0951, 'learning_rate': 4.386243386243387e-05, 'epoch': 0.83}
# {'loss': 0.0311, 'learning_rate': 4.380952380952381e-05, 'epoch': 0.84}
# {'loss': 0.1521, 'learning_rate': 4.3756613756613755e-05, 'epoch': 0.84}
# {'loss': 0.0839, 'learning_rate': 4.3703703703703705e-05, 'epoch': 0.85}
# {'loss': 0.0881, 'learning_rate': 4.3650793650793655e-05, 'epoch': 0.85}
# {'loss': 0.0333, 'learning_rate': 4.35978835978836e-05, 'epoch': 0.86}
# {'loss': 0.0844, 'learning_rate': 4.354497354497355e-05, 'epoch': 0.86}
# {'loss': 0.081, 'learning_rate': 4.34920634920635e-05, 'epoch': 0.87}
# {'loss': 0.1807, 'learning_rate': 4.343915343915344e-05, 'epoch': 0.87}
# {'loss': 0.0174, 'learning_rate': 4.3386243386243384e-05, 'epoch': 0.88}
# {'loss': 0.1438, 'learning_rate': 4.3333333333333334e-05, 'epoch': 0.88}
# {'loss': 0.1411, 'learning_rate': 4.3280423280423284e-05, 'epoch': 0.89}
# {'loss': 0.0682, 'learning_rate': 4.322751322751323e-05, 'epoch': 0.89}
# {'loss': 0.0535, 'learning_rate': 4.317460317460318e-05, 'epoch': 0.9}
# {'loss': 0.0959, 'learning_rate': 4.312169312169313e-05, 'epoch': 0.9}
# {'loss': 0.0532, 'learning_rate': 4.306878306878307e-05, 'epoch': 0.91}
# {'loss': 0.0534, 'learning_rate': 4.301587301587302e-05, 'epoch': 0.91}
# {'loss': 0.0922, 'learning_rate': 4.296296296296296e-05, 'epoch': 0.92}
# {'loss': 0.1571, 'learning_rate': 4.291005291005291e-05, 'epoch': 0.92}
# {'loss': 0.082, 'learning_rate': 4.2857142857142856e-05, 'epoch': 0.93}
# {'loss': 0.0603, 'learning_rate': 4.2804232804232806e-05, 'epoch': 0.93}
# {'loss': 0.084, 'learning_rate': 4.2751322751322756e-05, 'epoch': 0.94}
# {'loss': 0.0186, 'learning_rate': 4.26984126984127e-05, 'epoch': 0.94}
# {'loss': 0.0133, 'learning_rate': 4.264550264550265e-05, 'epoch': 0.95}
# {'loss': 0.1931, 'learning_rate': 4.259259259259259e-05, 'epoch': 0.95}
# {'loss': 0.0493, 'learning_rate': 4.253968253968254e-05, 'epoch': 0.96}
# {'loss': 0.065, 'learning_rate': 4.248677248677249e-05, 'epoch': 0.96}
# {'loss': 0.055, 'learning_rate': 4.2433862433862435e-05, 'epoch': 0.97}
# {'loss': 0.0968, 'learning_rate': 4.2380952380952385e-05, 'epoch': 0.97}
# {'loss': 0.0481, 'learning_rate': 4.232804232804233e-05, 'epoch': 0.98}
# {'loss': 0.1804, 'learning_rate': 4.227513227513228e-05, 'epoch': 0.98}
# {'loss': 0.0955, 'learning_rate': 4.222222222222222e-05, 'epoch': 0.99}
# {'loss': 0.0096, 'learning_rate': 4.216931216931217e-05, 'epoch': 0.99}
# {'loss': 0.0287, 'learning_rate': 4.211640211640212e-05, 'epoch': 1.0}
#   0%|          | 0/125 [00:00<?, ?it/s]
# {'eval_loss': 0.09325584024190903, 'eval_accuracy': 0.9766272932897713, 'eval_runtime': 2160.0997, 'eval_samples_per_second': 3.684, 'eval_steps_per_second': 0.058, 'epoch': 1.0}
# {'loss': 0.0322, 'learning_rate': 4.2063492063492065e-05, 'epoch': 1.01}
# {'loss': 0.0113, 'learning_rate': 4.2010582010582014e-05, 'epoch': 1.01}
# {'loss': 0.0946, 'learning_rate': 4.1957671957671964e-05, 'epoch': 1.02}
# {'loss': 0.142, 'learning_rate': 4.190476190476191e-05, 'epoch': 1.02}
# {'loss': 0.0734, 'learning_rate': 4.185185185185185e-05, 'epoch': 1.03}
# {'loss': 0.0378, 'learning_rate': 4.17989417989418e-05, 'epoch': 1.03}
# {'loss': 0.1043, 'learning_rate': 4.174603174603175e-05, 'epoch': 1.04}
# {'loss': 0.0868, 'learning_rate': 4.1693121693121694e-05, 'epoch': 1.04}
# {'loss': 0.0935, 'learning_rate': 4.1640211640211644e-05, 'epoch': 1.05}
# {'loss': 0.0926, 'learning_rate': 4.1587301587301594e-05, 'epoch': 1.05}
# {'loss': 0.003, 'learning_rate': 4.153439153439154e-05, 'epoch': 1.06}
# {'loss': 0.0649, 'learning_rate': 4.148148148148148e-05, 'epoch': 1.06}
# {'loss': 0.0019, 'learning_rate': 4.1428571428571437e-05, 'epoch': 1.07}
# {'loss': 0.0639, 'learning_rate': 4.137566137566138e-05, 'epoch': 1.07}
# {'loss': 0.0014, 'learning_rate': 4.132275132275132e-05, 'epoch': 1.08}
# {'loss': 0.0452, 'learning_rate': 4.126984126984127e-05, 'epoch': 1.08}
# {'loss': 0.1293, 'learning_rate': 4.121693121693122e-05, 'epoch': 1.09}
# {'loss': 0.0733, 'learning_rate': 4.1164021164021166e-05, 'epoch': 1.09}
# {'loss': 0.0301, 'learning_rate': 4.111111111111111e-05, 'epoch': 1.1}
# {'loss': 0.107, 'learning_rate': 4.105820105820106e-05, 'epoch': 1.1}
# {'loss': 0.0496, 'learning_rate': 4.100529100529101e-05, 'epoch': 1.11}
# {'loss': 0.0631, 'learning_rate': 4.095238095238095e-05, 'epoch': 1.11}
# {'loss': 0.0091, 'learning_rate': 4.08994708994709e-05, 'epoch': 1.12}
# {'loss': 0.0443, 'learning_rate': 4.084656084656085e-05, 'epoch': 1.12}
# {'loss': 0.087, 'learning_rate': 4.0793650793650795e-05, 'epoch': 1.13}
# {'loss': 0.0443, 'learning_rate': 4.074074074074074e-05, 'epoch': 1.13}
# {'loss': 0.0109, 'learning_rate': 4.068783068783069e-05, 'epoch': 1.14}
# {'loss': 0.0609, 'learning_rate': 4.063492063492064e-05, 'epoch': 1.14}
# {'loss': 0.0696, 'learning_rate': 4.058201058201058e-05, 'epoch': 1.15}
# {'loss': 0.0116, 'learning_rate': 4.052910052910053e-05, 'epoch': 1.15}
# {'loss': 0.1174, 'learning_rate': 4.047619047619048e-05, 'epoch': 1.16}
# {'loss': 0.0402, 'learning_rate': 4.0423280423280424e-05, 'epoch': 1.16}
# {'loss': 0.0697, 'learning_rate': 4.0370370370370374e-05, 'epoch': 1.17}
# {'loss': 0.0517, 'learning_rate': 4.031746031746032e-05, 'epoch': 1.17}
# {'loss': 0.0511, 'learning_rate': 4.026455026455027e-05, 'epoch': 1.18}
# {'loss': 0.0141, 'learning_rate': 4.021164021164021e-05, 'epoch': 1.18}
# {'loss': 0.0609, 'learning_rate': 4.015873015873016e-05, 'epoch': 1.19}
# {'loss': 0.0161, 'learning_rate': 4.010582010582011e-05, 'epoch': 1.19}
# {'loss': 0.0737, 'learning_rate': 4.005291005291005e-05, 'epoch': 1.2}
# {'loss': 0.0627, 'learning_rate': 4e-05, 'epoch': 1.2}
# {'loss': 0.044, 'learning_rate': 3.9947089947089946e-05, 'epoch': 1.21}
# {'loss': 0.053, 'learning_rate': 3.9894179894179896e-05, 'epoch': 1.21}
# {'loss': 0.0738, 'learning_rate': 3.984126984126984e-05, 'epoch': 1.22}
# {'loss': 0.074, 'learning_rate': 3.978835978835979e-05, 'epoch': 1.22}
# {'loss': 0.0838, 'learning_rate': 3.973544973544974e-05, 'epoch': 1.23}
# {'loss': 0.092, 'learning_rate': 3.968253968253968e-05, 'epoch': 1.23}
# {'loss': 0.0136, 'learning_rate': 3.962962962962963e-05, 'epoch': 1.24}
# {'loss': 0.0565, 'learning_rate': 3.9576719576719576e-05, 'epoch': 1.24}
# {'loss': 0.0163, 'learning_rate': 3.9523809523809526e-05, 'epoch': 1.25}
# {'loss': 0.0447, 'learning_rate': 3.9470899470899475e-05, 'epoch': 1.25}
# {'loss': 0.0132, 'learning_rate': 3.941798941798942e-05, 'epoch': 1.26}
# {'loss': 0.1122, 'learning_rate': 3.936507936507937e-05, 'epoch': 1.26}
# {'loss': 0.0047, 'learning_rate': 3.931216931216931e-05, 'epoch': 1.27}
# {'loss': 0.0912, 'learning_rate': 3.925925925925926e-05, 'epoch': 1.27}
# {'loss': 0.0491, 'learning_rate': 3.9206349206349205e-05, 'epoch': 1.28}
# {'loss': 0.1624, 'learning_rate': 3.9153439153439155e-05, 'epoch': 1.28}
# {'loss': 0.0511, 'learning_rate': 3.9100529100529105e-05, 'epoch': 1.29}
# {'loss': 0.0868, 'learning_rate': 3.904761904761905e-05, 'epoch': 1.29}
# {'loss': 0.067, 'learning_rate': 3.8994708994709e-05, 'epoch': 1.3}
# {'loss': 0.0239, 'learning_rate': 3.894179894179895e-05, 'epoch': 1.3}
# {'loss': 0.0149, 'learning_rate': 3.888888888888889e-05, 'epoch': 1.31}
# {'loss': 0.0611, 'learning_rate': 3.8835978835978834e-05, 'epoch': 1.31}
# {'loss': 0.086, 'learning_rate': 3.8783068783068784e-05, 'epoch': 1.32}
# {'loss': 0.0667, 'learning_rate': 3.8730158730158734e-05, 'epoch': 1.32}
# {'loss': 0.0188, 'learning_rate': 3.867724867724868e-05, 'epoch': 1.33}
# {'loss': 0.0015, 'learning_rate': 3.862433862433863e-05, 'epoch': 1.33}
# {'loss': 0.0037, 'learning_rate': 3.857142857142858e-05, 'epoch': 1.34}
# {'loss': 0.0136, 'learning_rate': 3.851851851851852e-05, 'epoch': 1.34}
# {'loss': 0.0175, 'learning_rate': 3.846560846560846e-05, 'epoch': 1.35}
# {'loss': 0.0509, 'learning_rate': 3.841269841269842e-05, 'epoch': 1.35}
# {'loss': 0.0619, 'learning_rate': 3.835978835978836e-05, 'epoch': 1.36}
# {'loss': 0.0431, 'learning_rate': 3.8306878306878306e-05, 'epoch': 1.36}
# {'loss': 0.0713, 'learning_rate': 3.8253968253968256e-05, 'epoch': 1.37}
# {'loss': 0.038, 'learning_rate': 3.8201058201058206e-05, 'epoch': 1.37}
# {'loss': 0.1056, 'learning_rate': 3.814814814814815e-05, 'epoch': 1.38}
# {'loss': 0.0663, 'learning_rate': 3.809523809523809e-05, 'epoch': 1.38}
# {'loss': 0.0637, 'learning_rate': 3.804232804232805e-05, 'epoch': 1.39}
# {'loss': 0.0902, 'learning_rate': 3.798941798941799e-05, 'epoch': 1.39}
# {'loss': 0.0725, 'learning_rate': 3.7936507936507935e-05, 'epoch': 1.4}
# {'loss': 0.0307, 'learning_rate': 3.7883597883597885e-05, 'epoch': 1.4}
# {'loss': 0.0711, 'learning_rate': 3.7830687830687835e-05, 'epoch': 1.41}
# {'loss': 0.0489, 'learning_rate': 3.777777777777778e-05, 'epoch': 1.41}
# {'loss': 0.0474, 'learning_rate': 3.772486772486772e-05, 'epoch': 1.42}
# {'loss': 0.0215, 'learning_rate': 3.767195767195768e-05, 'epoch': 1.42}
# {'loss': 0.1306, 'learning_rate': 3.761904761904762e-05, 'epoch': 1.43}
# {'loss': 0.0074, 'learning_rate': 3.7566137566137564e-05, 'epoch': 1.43}
# {'loss': 0.082, 'learning_rate': 3.7513227513227514e-05, 'epoch': 1.44}
# {'loss': 0.0832, 'learning_rate': 3.7460317460317464e-05, 'epoch': 1.44}
# {'loss': 0.0436, 'learning_rate': 3.740740740740741e-05, 'epoch': 1.45}
# {'loss': 0.0664, 'learning_rate': 3.735449735449736e-05, 'epoch': 1.45}
# {'loss': 0.0411, 'learning_rate': 3.730158730158731e-05, 'epoch': 1.46}
# {'loss': 0.0234, 'learning_rate': 3.724867724867725e-05, 'epoch': 1.46}
# {'loss': 0.0349, 'learning_rate': 3.7195767195767194e-05, 'epoch': 1.47}
# {'loss': 0.0646, 'learning_rate': 3.7142857142857143e-05, 'epoch': 1.47}
# {'loss': 0.0356, 'learning_rate': 3.7089947089947093e-05, 'epoch': 1.48}
# {'loss': 0.0721, 'learning_rate': 3.7037037037037037e-05, 'epoch': 1.48}
# {'loss': 0.0025, 'learning_rate': 3.6984126984126986e-05, 'epoch': 1.49}
# {'loss': 0.0296, 'learning_rate': 3.6931216931216936e-05, 'epoch': 1.49}
# {'loss': 0.0535, 'learning_rate': 3.687830687830688e-05, 'epoch': 1.5}
# {'loss': 0.0542, 'learning_rate': 3.682539682539683e-05, 'epoch': 1.5}
# {'loss': 0.0503, 'learning_rate': 3.677248677248677e-05, 'epoch': 1.51}
# {'loss': 0.0712, 'learning_rate': 3.671957671957672e-05, 'epoch': 1.51}
# {'loss': 0.0316, 'learning_rate': 3.6666666666666666e-05, 'epoch': 1.52}
# {'loss': 0.1399, 'learning_rate': 3.6613756613756616e-05, 'epoch': 1.52}
# {'loss': 0.0328, 'learning_rate': 3.6560846560846566e-05, 'epoch': 1.53}
# {'loss': 0.076, 'learning_rate': 3.650793650793651e-05, 'epoch': 1.53}
# {'loss': 0.0317, 'learning_rate': 3.645502645502646e-05, 'epoch': 1.54}
# {'loss': 0.0033, 'learning_rate': 3.64021164021164e-05, 'epoch': 1.54}
# {'loss': 0.0105, 'learning_rate': 3.634920634920635e-05, 'epoch': 1.55}
# {'loss': 0.0917, 'learning_rate': 3.62962962962963e-05, 'epoch': 1.55}
# {'loss': 0.1633, 'learning_rate': 3.6243386243386245e-05, 'epoch': 1.56}
# {'loss': 0.0005, 'learning_rate': 3.619047619047619e-05, 'epoch': 1.56}
# {'loss': 0.0675, 'learning_rate': 3.613756613756614e-05, 'epoch': 1.57}
# {'loss': 0.0221, 'learning_rate': 3.608465608465609e-05, 'epoch': 1.57}
# {'loss': 0.1033, 'learning_rate': 3.603174603174603e-05, 'epoch': 1.58}
# {'loss': 0.1061, 'learning_rate': 3.597883597883598e-05, 'epoch': 1.58}
# {'loss': 0.0271, 'learning_rate': 3.592592592592593e-05, 'epoch': 1.59}
# {'loss': 0.1039, 'learning_rate': 3.5873015873015874e-05, 'epoch': 1.59}
# {'loss': 0.044, 'learning_rate': 3.582010582010582e-05, 'epoch': 1.6}
# {'loss': 0.0582, 'learning_rate': 3.5767195767195774e-05, 'epoch': 1.6}
# {'loss': 0.0206, 'learning_rate': 3.571428571428572e-05, 'epoch': 1.61}
# {'loss': 0.0455, 'learning_rate': 3.566137566137566e-05, 'epoch': 1.61}
# {'loss': 0.009, 'learning_rate': 3.560846560846561e-05, 'epoch': 1.62}
# {'loss': 0.0615, 'learning_rate': 3.555555555555556e-05, 'epoch': 1.62}
# {'loss': 0.1341, 'learning_rate': 3.55026455026455e-05, 'epoch': 1.63}
# {'loss': 0.0809, 'learning_rate': 3.5449735449735446e-05, 'epoch': 1.63}
# {'loss': 0.0848, 'learning_rate': 3.53968253968254e-05, 'epoch': 1.64}
# {'loss': 0.0722, 'learning_rate': 3.5343915343915346e-05, 'epoch': 1.64}
# {'loss': 0.0403, 'learning_rate': 3.529100529100529e-05, 'epoch': 1.65}
# {'loss': 0.0236, 'learning_rate': 3.523809523809524e-05, 'epoch': 1.65}
# {'loss': 0.0464, 'learning_rate': 3.518518518518519e-05, 'epoch': 1.66}
# {'loss': 0.0253, 'learning_rate': 3.513227513227513e-05, 'epoch': 1.66}
# {'loss': 0.0433, 'learning_rate': 3.5079365079365075e-05, 'epoch': 1.67}
# {'loss': 0.0675, 'learning_rate': 3.502645502645503e-05, 'epoch': 1.67}
# {'loss': 0.0014, 'learning_rate': 3.4973544973544975e-05, 'epoch': 1.68}
# {'loss': 0.0658, 'learning_rate': 3.492063492063492e-05, 'epoch': 1.68}
# {'loss': 0.0461, 'learning_rate': 3.486772486772487e-05, 'epoch': 1.69}
# {'loss': 0.0242, 'learning_rate': 3.481481481481482e-05, 'epoch': 1.69}
# {'loss': 0.0392, 'learning_rate': 3.476190476190476e-05, 'epoch': 1.7}
# {'loss': 0.0006, 'learning_rate': 3.470899470899471e-05, 'epoch': 1.7}
# {'loss': 0.1134, 'learning_rate': 3.465608465608466e-05, 'epoch': 1.71}
# {'loss': 0.0238, 'learning_rate': 3.4603174603174604e-05, 'epoch': 1.71}
# {'loss': 0.1333, 'learning_rate': 3.455026455026455e-05, 'epoch': 1.72}
# {'loss': 0.0935, 'learning_rate': 3.44973544973545e-05, 'epoch': 1.72}
# {'loss': 0.0449, 'learning_rate': 3.444444444444445e-05, 'epoch': 1.73}
# {'loss': 0.0348, 'learning_rate': 3.439153439153439e-05, 'epoch': 1.73}
# {'loss': 0.0042, 'learning_rate': 3.433862433862434e-05, 'epoch': 1.74}
# {'loss': 0.0132, 'learning_rate': 3.428571428571429e-05, 'epoch': 1.74}
# {'loss': 0.0174, 'learning_rate': 3.4232804232804234e-05, 'epoch': 1.75}
# {'loss': 0.0028, 'learning_rate': 3.4179894179894184e-05, 'epoch': 1.75}
# {'loss': 0.0238, 'learning_rate': 3.412698412698413e-05, 'epoch': 1.76}
# {'loss': 0.0953, 'learning_rate': 3.4074074074074077e-05, 'epoch': 1.76}
# {'loss': 0.0641, 'learning_rate': 3.402116402116402e-05, 'epoch': 1.77}
# {'loss': 0.0334, 'learning_rate': 3.396825396825397e-05, 'epoch': 1.77}
# {'loss': 0.0976, 'learning_rate': 3.391534391534392e-05, 'epoch': 1.78}
# {'loss': 0.0417, 'learning_rate': 3.386243386243386e-05, 'epoch': 1.78}
# {'loss': 0.0034, 'learning_rate': 3.380952380952381e-05, 'epoch': 1.79}
# {'loss': 0.0076, 'learning_rate': 3.3756613756613756e-05, 'epoch': 1.79}
# {'loss': 0.0439, 'learning_rate': 3.3703703703703706e-05, 'epoch': 1.8}
# {'loss': 0.0404, 'learning_rate': 3.3650793650793656e-05, 'epoch': 1.8}
# {'loss': 0.0167, 'learning_rate': 3.35978835978836e-05, 'epoch': 1.81}
# {'loss': 0.1496, 'learning_rate': 3.354497354497355e-05, 'epoch': 1.81}
# {'loss': 0.0738, 'learning_rate': 3.349206349206349e-05, 'epoch': 1.82}
# {'loss': 0.0516, 'learning_rate': 3.343915343915344e-05, 'epoch': 1.82}
# {'loss': 0.0222, 'learning_rate': 3.3386243386243385e-05, 'epoch': 1.83}
# {'loss': 0.0924, 'learning_rate': 3.3333333333333335e-05, 'epoch': 1.83}
# {'loss': 0.0114, 'learning_rate': 3.3280423280423285e-05, 'epoch': 1.84}
# {'loss': 0.0629, 'learning_rate': 3.322751322751323e-05, 'epoch': 1.84}
# {'loss': 0.0462, 'learning_rate': 3.317460317460318e-05, 'epoch': 1.85}
# {'loss': 0.0008, 'learning_rate': 3.312169312169313e-05, 'epoch': 1.85}
# {'loss': 0.0876, 'learning_rate': 3.306878306878307e-05, 'epoch': 1.86}
# {'loss': 0.04, 'learning_rate': 3.3015873015873014e-05, 'epoch': 1.86}
# {'loss': 0.1052, 'learning_rate': 3.2962962962962964e-05, 'epoch': 1.87}
# {'loss': 0.0034, 'learning_rate': 3.2910052910052914e-05, 'epoch': 1.87}
# {'loss': 0.0336, 'learning_rate': 3.285714285714286e-05, 'epoch': 1.88}
# {'loss': 0.0369, 'learning_rate': 3.280423280423281e-05, 'epoch': 1.88}
# {'loss': 0.0994, 'learning_rate': 3.275132275132276e-05, 'epoch': 1.89}
# {'loss': 0.0768, 'learning_rate': 3.26984126984127e-05, 'epoch': 1.89}
# {'loss': 0.0125, 'learning_rate': 3.264550264550264e-05, 'epoch': 1.9}
# {'loss': 0.1192, 'learning_rate': 3.25925925925926e-05, 'epoch': 1.9}
# {'loss': 0.1023, 'learning_rate': 3.253968253968254e-05, 'epoch': 1.91}
# {'loss': 0.0218, 'learning_rate': 3.2486772486772486e-05, 'epoch': 1.91}
# {'loss': 0.0128, 'learning_rate': 3.2433862433862436e-05, 'epoch': 1.92}
# {'loss': 0.0797, 'learning_rate': 3.2380952380952386e-05, 'epoch': 1.92}
# {'loss': 0.0446, 'learning_rate': 3.232804232804233e-05, 'epoch': 1.93}
# {'loss': 0.0111, 'learning_rate': 3.227513227513227e-05, 'epoch': 1.93}
# {'loss': 0.0375, 'learning_rate': 3.222222222222223e-05, 'epoch': 1.94}
# {'loss': 0.0174, 'learning_rate': 3.216931216931217e-05, 'epoch': 1.94}
# {'loss': 0.0106, 'learning_rate': 3.2116402116402115e-05, 'epoch': 1.95}
# {'loss': 0.1315, 'learning_rate': 3.2063492063492065e-05, 'epoch': 1.95}
# {'loss': 0.0371, 'learning_rate': 3.2010582010582015e-05, 'epoch': 1.96}
# {'loss': 0.0352, 'learning_rate': 3.195767195767196e-05, 'epoch': 1.96}
# {'loss': 0.0653, 'learning_rate': 3.19047619047619e-05, 'epoch': 1.97}
# {'loss': 0.039, 'learning_rate': 3.185185185185185e-05, 'epoch': 1.97}
# {'loss': 0.0337, 'learning_rate': 3.17989417989418e-05, 'epoch': 1.98}
# {'loss': 0.0307, 'learning_rate': 3.1746031746031745e-05, 'epoch': 1.98}
# {'loss': 0.0018, 'learning_rate': 3.1693121693121695e-05, 'epoch': 1.99}
# {'loss': 0.0566, 'learning_rate': 3.1640211640211645e-05, 'epoch': 1.99}
# {'loss': 0.0718, 'learning_rate': 3.158730158730159e-05, 'epoch': 2.0}
#   0%|          | 0/125 [00:00<?, ?it/s]
# {'eval_loss': 0.07694826275110245, 'eval_accuracy': 0.9832872581050516, 'eval_runtime': 382.1057, 'eval_samples_per_second': 20.827, 'eval_steps_per_second': 0.327, 'epoch': 2.0}
# {'loss': 0.0232, 'learning_rate': 3.153439153439154e-05, 'epoch': 2.01}
# {'loss': 0.0114, 'learning_rate': 3.148148148148148e-05, 'epoch': 2.01}
# {'loss': 0.0415, 'learning_rate': 3.142857142857143e-05, 'epoch': 2.02}
# {'loss': 0.0063, 'learning_rate': 3.1375661375661374e-05, 'epoch': 2.02}
# {'loss': 0.0004, 'learning_rate': 3.1322751322751324e-05, 'epoch': 2.03}
# {'loss': 0.0029, 'learning_rate': 3.1269841269841274e-05, 'epoch': 2.03}
# {'loss': 0.0359, 'learning_rate': 3.121693121693122e-05, 'epoch': 2.04}
# {'loss': 0.0258, 'learning_rate': 3.116402116402117e-05, 'epoch': 2.04}
# {'loss': 0.016, 'learning_rate': 3.111111111111111e-05, 'epoch': 2.05}
# {'loss': 0.0205, 'learning_rate': 3.105820105820106e-05, 'epoch': 2.05}
# {'loss': 0.1145, 'learning_rate': 3.100529100529101e-05, 'epoch': 2.06}
# {'loss': 0.0207, 'learning_rate': 3.095238095238095e-05, 'epoch': 2.06}
# {'loss': 0.0027, 'learning_rate': 3.08994708994709e-05, 'epoch': 2.07}
# {'loss': 0.1041, 'learning_rate': 3.0846560846560846e-05, 'epoch': 2.07}
# {'loss': 0.0359, 'learning_rate': 3.0793650793650796e-05, 'epoch': 2.08}
# {'loss': 0.0539, 'learning_rate': 3.074074074074074e-05, 'epoch': 2.08}
# {'loss': 0.0435, 'learning_rate': 3.068783068783069e-05, 'epoch': 2.09}
# {'loss': 0.0007, 'learning_rate': 3.063492063492064e-05, 'epoch': 2.09}
# {'loss': 0.036, 'learning_rate': 3.058201058201058e-05, 'epoch': 2.1}
# {'loss': 0.0365, 'learning_rate': 3.052910052910053e-05, 'epoch': 2.1}
# {'loss': 0.0005, 'learning_rate': 3.0476190476190482e-05, 'epoch': 2.11}
# {'loss': 0.0243, 'learning_rate': 3.0423280423280425e-05, 'epoch': 2.11}
# {'loss': 0.007, 'learning_rate': 3.037037037037037e-05, 'epoch': 2.12}
# {'loss': 0.0252, 'learning_rate': 3.0317460317460318e-05, 'epoch': 2.12}
# {'loss': 0.0022, 'learning_rate': 3.0264550264550268e-05, 'epoch': 2.13}
# {'loss': 0.0059, 'learning_rate': 3.0211640211640215e-05, 'epoch': 2.13}
# {'loss': 0.0075, 'learning_rate': 3.0158730158730158e-05, 'epoch': 2.14}
# {'loss': 0.0303, 'learning_rate': 3.010582010582011e-05, 'epoch': 2.14}
# {'loss': 0.0007, 'learning_rate': 3.0052910052910054e-05, 'epoch': 2.15}
# {'loss': 0.0172, 'learning_rate': 3e-05, 'epoch': 2.15}
# {'loss': 0.0004, 'learning_rate': 2.9947089947089947e-05, 'epoch': 2.16}
# {'loss': 0.0005, 'learning_rate': 2.9894179894179897e-05, 'epoch': 2.16}
# {'loss': 0.0009, 'learning_rate': 2.9841269841269844e-05, 'epoch': 2.17}
# {'loss': 0.0341, 'learning_rate': 2.9788359788359787e-05, 'epoch': 2.17}
# {'loss': 0.0003, 'learning_rate': 2.973544973544974e-05, 'epoch': 2.18}
# {'loss': 0.03, 'learning_rate': 2.9682539682539683e-05, 'epoch': 2.18}
# {'loss': 0.0491, 'learning_rate': 2.962962962962963e-05, 'epoch': 2.19}
# {'loss': 0.0003, 'learning_rate': 2.957671957671958e-05, 'epoch': 2.19}
# {'loss': 0.0127, 'learning_rate': 2.9523809523809526e-05, 'epoch': 2.2}
# {'loss': 0.1074, 'learning_rate': 2.9470899470899473e-05, 'epoch': 2.2}
# {'loss': 0.0611, 'learning_rate': 2.9417989417989416e-05, 'epoch': 2.21}
# {'loss': 0.0046, 'learning_rate': 2.9365079365079366e-05, 'epoch': 2.21}
# {'loss': 0.0942, 'learning_rate': 2.9312169312169313e-05, 'epoch': 2.22}
# {'loss': 0.0621, 'learning_rate': 2.925925925925926e-05, 'epoch': 2.22}
# {'loss': 0.0233, 'learning_rate': 2.920634920634921e-05, 'epoch': 2.23}
# {'loss': 0.0205, 'learning_rate': 2.9153439153439156e-05, 'epoch': 2.23}
# {'loss': 0.0052, 'learning_rate': 2.91005291005291e-05, 'epoch': 2.24}
# {'loss': 0.0269, 'learning_rate': 2.9047619047619052e-05, 'epoch': 2.24}
# {'loss': 0.0008, 'learning_rate': 2.8994708994708995e-05, 'epoch': 2.25}
# {'loss': 0.031, 'learning_rate': 2.8941798941798942e-05, 'epoch': 2.25}
# {'loss': 0.0379, 'learning_rate': 2.8888888888888888e-05, 'epoch': 2.26}
# {'loss': 0.0024, 'learning_rate': 2.8835978835978838e-05, 'epoch': 2.26}
# {'loss': 0.0608, 'learning_rate': 2.8783068783068785e-05, 'epoch': 2.27}
# {'loss': 0.0002, 'learning_rate': 2.8730158730158728e-05, 'epoch': 2.27}
# {'loss': 0.0562, 'learning_rate': 2.867724867724868e-05, 'epoch': 2.28}
# {'loss': 0.0105, 'learning_rate': 2.8624338624338624e-05, 'epoch': 2.28}
# {'loss': 0.0311, 'learning_rate': 2.857142857142857e-05, 'epoch': 2.29}
# {'loss': 0.0273, 'learning_rate': 2.851851851851852e-05, 'epoch': 2.29}
# {'loss': 0.0031, 'learning_rate': 2.8465608465608467e-05, 'epoch': 2.3}
# {'loss': 0.0105, 'learning_rate': 2.8412698412698414e-05, 'epoch': 2.3}
# {'loss': 0.0074, 'learning_rate': 2.8359788359788357e-05, 'epoch': 2.31}
# {'loss': 0.0149, 'learning_rate': 2.830687830687831e-05, 'epoch': 2.31}
# {'loss': 0.0377, 'learning_rate': 2.8253968253968253e-05, 'epoch': 2.32}
# {'loss': 0.0751, 'learning_rate': 2.82010582010582e-05, 'epoch': 2.32}
# {'loss': 0.0425, 'learning_rate': 2.814814814814815e-05, 'epoch': 2.33}
# {'loss': 0.0816, 'learning_rate': 2.8095238095238096e-05, 'epoch': 2.33}
# {'loss': 0.0053, 'learning_rate': 2.8042328042328043e-05, 'epoch': 2.34}
# {'loss': 0.0014, 'learning_rate': 2.7989417989417993e-05, 'epoch': 2.34}
# {'loss': 0.036, 'learning_rate': 2.793650793650794e-05, 'epoch': 2.35}
# {'loss': 0.0002, 'learning_rate': 2.7883597883597883e-05, 'epoch': 2.35}
# {'loss': 0.0895, 'learning_rate': 2.783068783068783e-05, 'epoch': 2.36}
# {'loss': 0.0128, 'learning_rate': 2.777777777777778e-05, 'epoch': 2.36}
# {'loss': 0.0269, 'learning_rate': 2.7724867724867726e-05, 'epoch': 2.37}
# {'loss': 0.0013, 'learning_rate': 2.7671957671957672e-05, 'epoch': 2.37}
# {'loss': 0.0607, 'learning_rate': 2.7619047619047622e-05, 'epoch': 2.38}
# {'loss': 0.0066, 'learning_rate': 2.756613756613757e-05, 'epoch': 2.38}
# {'loss': 0.003, 'learning_rate': 2.7513227513227512e-05, 'epoch': 2.39}
# {'loss': 0.0034, 'learning_rate': 2.7460317460317465e-05, 'epoch': 2.39}
# {'loss': 0.0043, 'learning_rate': 2.7407407407407408e-05, 'epoch': 2.4}
# {'loss': 0.0007, 'learning_rate': 2.7354497354497355e-05, 'epoch': 2.4}
# {'loss': 0.104, 'learning_rate': 2.73015873015873e-05, 'epoch': 2.41}
# {'loss': 0.0376, 'learning_rate': 2.724867724867725e-05, 'epoch': 2.41}
# {'loss': 0.072, 'learning_rate': 2.7195767195767198e-05, 'epoch': 2.42}
# {'loss': 0.0959, 'learning_rate': 2.714285714285714e-05, 'epoch': 2.42}
# {'loss': 0.0006, 'learning_rate': 2.7089947089947094e-05, 'epoch': 2.43}
# {'loss': 0.0109, 'learning_rate': 2.7037037037037037e-05, 'epoch': 2.43}
# {'loss': 0.0051, 'learning_rate': 2.6984126984126984e-05, 'epoch': 2.44}
# {'loss': 0.0599, 'learning_rate': 2.6931216931216934e-05, 'epoch': 2.44}
# {'loss': 0.0003, 'learning_rate': 2.687830687830688e-05, 'epoch': 2.45}
# {'loss': 0.0064, 'learning_rate': 2.6825396825396827e-05, 'epoch': 2.45}
# {'loss': 0.0181, 'learning_rate': 2.677248677248677e-05, 'epoch': 2.46}
# {'loss': 0.0053, 'learning_rate': 2.6719576719576723e-05, 'epoch': 2.46}
# {'loss': 0.0264, 'learning_rate': 2.6666666666666667e-05, 'epoch': 2.47}
# {'loss': 0.0013, 'learning_rate': 2.6613756613756613e-05, 'epoch': 2.47}
# {'loss': 0.0233, 'learning_rate': 2.6560846560846563e-05, 'epoch': 2.48}
# {'loss': 0.0383, 'learning_rate': 2.650793650793651e-05, 'epoch': 2.48}
# {'loss': 0.0936, 'learning_rate': 2.6455026455026456e-05, 'epoch': 2.49}
# {'loss': 0.0019, 'learning_rate': 2.6402116402116406e-05, 'epoch': 2.49}
# {'loss': 0.0098, 'learning_rate': 2.6349206349206353e-05, 'epoch': 2.5}
# {'loss': 0.0283, 'learning_rate': 2.6296296296296296e-05, 'epoch': 2.5}
# {'loss': 0.0092, 'learning_rate': 2.6243386243386242e-05, 'epoch': 2.51}
# {'loss': 0.0254, 'learning_rate': 2.6190476190476192e-05, 'epoch': 2.51}
# {'loss': 0.0403, 'learning_rate': 2.613756613756614e-05, 'epoch': 2.52}
# {'loss': 0.1002, 'learning_rate': 2.6084656084656085e-05, 'epoch': 2.52}
# {'loss': 0.0783, 'learning_rate': 2.6031746031746035e-05, 'epoch': 2.53}
# {'loss': 0.0668, 'learning_rate': 2.5978835978835982e-05, 'epoch': 2.53}
# {'loss': 0.0204, 'learning_rate': 2.5925925925925925e-05, 'epoch': 2.54}
# {'loss': 0.0164, 'learning_rate': 2.5873015873015878e-05, 'epoch': 2.54}
# {'loss': 0.0106, 'learning_rate': 2.582010582010582e-05, 'epoch': 2.55}
# {'loss': 0.0269, 'learning_rate': 2.5767195767195768e-05, 'epoch': 2.55}
# {'loss': 0.0596, 'learning_rate': 2.5714285714285714e-05, 'epoch': 2.56}
# {'loss': 0.0006, 'learning_rate': 2.5661375661375664e-05, 'epoch': 2.56}
# {'loss': 0.0293, 'learning_rate': 2.560846560846561e-05, 'epoch': 2.57}
# {'loss': 0.0017, 'learning_rate': 2.5555555555555554e-05, 'epoch': 2.57}
# {'loss': 0.0014, 'learning_rate': 2.5502645502645507e-05, 'epoch': 2.58}
# {'loss': 0.0099, 'learning_rate': 2.544973544973545e-05, 'epoch': 2.58}
# {'loss': 0.0278, 'learning_rate': 2.5396825396825397e-05, 'epoch': 2.59}
# {'loss': 0.0004, 'learning_rate': 2.5343915343915347e-05, 'epoch': 2.59}
# {'loss': 0.0193, 'learning_rate': 2.5291005291005294e-05, 'epoch': 2.6}
# {'loss': 0.0003, 'learning_rate': 2.523809523809524e-05, 'epoch': 2.6}
# {'loss': 0.0169, 'learning_rate': 2.5185185185185183e-05, 'epoch': 2.61}
# {'loss': 0.0335, 'learning_rate': 2.5132275132275137e-05, 'epoch': 2.61}
# {'loss': 0.0744, 'learning_rate': 2.507936507936508e-05, 'epoch': 2.62}
# {'loss': 0.004, 'learning_rate': 2.5026455026455026e-05, 'epoch': 2.62}
# {'loss': 0.0022, 'learning_rate': 2.4973544973544973e-05, 'epoch': 2.63}
# {'loss': 0.0417, 'learning_rate': 2.4920634920634923e-05, 'epoch': 2.63}
# {'loss': 0.0003, 'learning_rate': 2.4867724867724866e-05, 'epoch': 2.64}
# {'loss': 0.0004, 'learning_rate': 2.4814814814814816e-05, 'epoch': 2.64}
# {'loss': 0.0021, 'learning_rate': 2.4761904761904762e-05, 'epoch': 2.65}
# {'loss': 0.0003, 'learning_rate': 2.470899470899471e-05, 'epoch': 2.65}
# {'loss': 0.0539, 'learning_rate': 2.465608465608466e-05, 'epoch': 2.66}
# {'loss': 0.0222, 'learning_rate': 2.4603174603174602e-05, 'epoch': 2.66}
# {'loss': 0.0033, 'learning_rate': 2.4550264550264552e-05, 'epoch': 2.67}
# {'loss': 0.024, 'learning_rate': 2.44973544973545e-05, 'epoch': 2.67}
# {'loss': 0.0005, 'learning_rate': 2.4444444444444445e-05, 'epoch': 2.68}
# {'loss': 0.0148, 'learning_rate': 2.439153439153439e-05, 'epoch': 2.68}
# {'loss': 0.004, 'learning_rate': 2.4338624338624338e-05, 'epoch': 2.69}
# {'loss': 0.0001, 'learning_rate': 2.4285714285714288e-05, 'epoch': 2.69}
# {'loss': 0.0006, 'learning_rate': 2.4232804232804234e-05, 'epoch': 2.7}
# {'loss': 0.0005, 'learning_rate': 2.417989417989418e-05, 'epoch': 2.7}
# {'loss': 0.0542, 'learning_rate': 2.4126984126984128e-05, 'epoch': 2.71}
# {'loss': 0.0014, 'learning_rate': 2.4074074074074074e-05, 'epoch': 2.71}
# {'loss': 0.0398, 'learning_rate': 2.402116402116402e-05, 'epoch': 2.72}
# {'loss': 0.0632, 'learning_rate': 2.396825396825397e-05, 'epoch': 2.72}
# {'loss': 0.0087, 'learning_rate': 2.3915343915343917e-05, 'epoch': 2.73}
# {'loss': 0.082, 'learning_rate': 2.3862433862433864e-05, 'epoch': 2.73}
# {'loss': 0.1046, 'learning_rate': 2.380952380952381e-05, 'epoch': 2.74}
# {'loss': 0.0642, 'learning_rate': 2.3756613756613757e-05, 'epoch': 2.74}
# {'loss': 0.0003, 'learning_rate': 2.3703703703703707e-05, 'epoch': 2.75}
# {'loss': 0.1311, 'learning_rate': 2.365079365079365e-05, 'epoch': 2.75}
# {'loss': 0.011, 'learning_rate': 2.35978835978836e-05, 'epoch': 2.76}
# {'loss': 0.0589, 'learning_rate': 2.3544973544973546e-05, 'epoch': 2.76}
# {'loss': 0.0648, 'learning_rate': 2.3492063492063493e-05, 'epoch': 2.77}
# {'loss': 0.0017, 'learning_rate': 2.3439153439153443e-05, 'epoch': 2.77}
# {'loss': 0.0155, 'learning_rate': 2.3386243386243386e-05, 'epoch': 2.78}
# {'loss': 0.0046, 'learning_rate': 2.3333333333333336e-05, 'epoch': 2.78}
# {'loss': 0.0018, 'learning_rate': 2.328042328042328e-05, 'epoch': 2.79}
# {'loss': 0.0015, 'learning_rate': 2.322751322751323e-05, 'epoch': 2.79}
# {'loss': 0.0476, 'learning_rate': 2.3174603174603175e-05, 'epoch': 2.8}
# {'loss': 0.014, 'learning_rate': 2.3121693121693122e-05, 'epoch': 2.8}
# {'loss': 0.0366, 'learning_rate': 2.3068783068783072e-05, 'epoch': 2.81}
# {'loss': 0.0371, 'learning_rate': 2.3015873015873015e-05, 'epoch': 2.81}
# {'loss': 0.0246, 'learning_rate': 2.2962962962962965e-05, 'epoch': 2.82}
# {'loss': 0.0138, 'learning_rate': 2.291005291005291e-05, 'epoch': 2.82}
# {'loss': 0.0022, 'learning_rate': 2.2857142857142858e-05, 'epoch': 2.83}
# {'loss': 0.0434, 'learning_rate': 2.2804232804232805e-05, 'epoch': 2.83}
# {'loss': 0.0294, 'learning_rate': 2.275132275132275e-05, 'epoch': 2.84}
# {'loss': 0.0027, 'learning_rate': 2.2698412698412698e-05, 'epoch': 2.84}
# {'loss': 0.0002, 'learning_rate': 2.2645502645502648e-05, 'epoch': 2.85}
# {'loss': 0.0025, 'learning_rate': 2.2592592592592594e-05, 'epoch': 2.85}
# {'loss': 0.0484, 'learning_rate': 2.253968253968254e-05, 'epoch': 2.86}
# {'loss': 0.0339, 'learning_rate': 2.2486772486772487e-05, 'epoch': 2.86}
# {'loss': 0.0006, 'learning_rate': 2.2433862433862434e-05, 'epoch': 2.87}
# {'loss': 0.0436, 'learning_rate': 2.2380952380952384e-05, 'epoch': 2.87}
# {'loss': 0.0004, 'learning_rate': 2.2328042328042327e-05, 'epoch': 2.88}
# {'loss': 0.0237, 'learning_rate': 2.2275132275132277e-05, 'epoch': 2.88}
# {'loss': 0.0002, 'learning_rate': 2.2222222222222223e-05, 'epoch': 2.89}
# {'loss': 0.0002, 'learning_rate': 2.216931216931217e-05, 'epoch': 2.89}
# {'loss': 0.0742, 'learning_rate': 2.211640211640212e-05, 'epoch': 2.9}
# {'loss': 0.0015, 'learning_rate': 2.2063492063492063e-05, 'epoch': 2.9}
# {'loss': 0.0017, 'learning_rate': 2.2010582010582013e-05, 'epoch': 2.91}
# {'loss': 0.0179, 'learning_rate': 2.1957671957671956e-05, 'epoch': 2.91}
# {'loss': 0.0005, 'learning_rate': 2.1904761904761906e-05, 'epoch': 2.92}
# {'loss': 0.021, 'learning_rate': 2.1851851851851852e-05, 'epoch': 2.92}
# {'loss': 0.005, 'learning_rate': 2.17989417989418e-05, 'epoch': 2.93}
# {'loss': 0.0002, 'learning_rate': 2.174603174603175e-05, 'epoch': 2.93}
# {'loss': 0.0031, 'learning_rate': 2.1693121693121692e-05, 'epoch': 2.94}
# {'loss': 0.0006, 'learning_rate': 2.1640211640211642e-05, 'epoch': 2.94}
# {'loss': 0.0011, 'learning_rate': 2.158730158730159e-05, 'epoch': 2.95}
# {'loss': 0.0005, 'learning_rate': 2.1534391534391535e-05, 'epoch': 2.95}
# {'loss': 0.0267, 'learning_rate': 2.148148148148148e-05, 'epoch': 2.96}
# {'loss': 0.0036, 'learning_rate': 2.1428571428571428e-05, 'epoch': 2.96}
# {'loss': 0.0004, 'learning_rate': 2.1375661375661378e-05, 'epoch': 2.97}
# {'loss': 0.0037, 'learning_rate': 2.1322751322751325e-05, 'epoch': 2.97}
# {'loss': 0.0515, 'learning_rate': 2.126984126984127e-05, 'epoch': 2.98}
# {'loss': 0.0496, 'learning_rate': 2.1216931216931218e-05, 'epoch': 2.98}
# {'loss': 0.0517, 'learning_rate': 2.1164021164021164e-05, 'epoch': 2.99}
# {'loss': 0.0001, 'learning_rate': 2.111111111111111e-05, 'epoch': 2.99}
# {'loss': 0.024, 'learning_rate': 2.105820105820106e-05, 'epoch': 3.0}
#   0%|          | 0/125 [00:00<?, ?it/s]
# {'eval_loss': 0.08927801251411438, 'eval_accuracy': 0.9846695149535059, 'eval_runtime': 358.5592, 'eval_samples_per_second': 22.194, 'eval_steps_per_second': 0.349, 'epoch': 3.0}
# {'loss': 0.0005, 'learning_rate': 2.1005291005291007e-05, 'epoch': 3.01}
# {'loss': 0.0062, 'learning_rate': 2.0952380952380954e-05, 'epoch': 3.01}
# {'loss': 0.0001, 'learning_rate': 2.08994708994709e-05, 'epoch': 3.02}
# {'loss': 0.0005, 'learning_rate': 2.0846560846560847e-05, 'epoch': 3.02}
# {'loss': 0.0172, 'learning_rate': 2.0793650793650797e-05, 'epoch': 3.03}
# {'loss': 0.0001, 'learning_rate': 2.074074074074074e-05, 'epoch': 3.03}
# {'loss': 0.0002, 'learning_rate': 2.068783068783069e-05, 'epoch': 3.04}
# {'loss': 0.0002, 'learning_rate': 2.0634920634920636e-05, 'epoch': 3.04}
# {'loss': 0.0002, 'learning_rate': 2.0582010582010583e-05, 'epoch': 3.05}
# {'loss': 0.0381, 'learning_rate': 2.052910052910053e-05, 'epoch': 3.05}
# {'loss': 0.0004, 'learning_rate': 2.0476190476190476e-05, 'epoch': 3.06}
# {'loss': 0.0169, 'learning_rate': 2.0423280423280426e-05, 'epoch': 3.06}
# {'loss': 0.0027, 'learning_rate': 2.037037037037037e-05, 'epoch': 3.07}
# {'loss': 0.0001, 'learning_rate': 2.031746031746032e-05, 'epoch': 3.07}
# {'loss': 0.001, 'learning_rate': 2.0264550264550266e-05, 'epoch': 3.08}
# {'loss': 0.0293, 'learning_rate': 2.0211640211640212e-05, 'epoch': 3.08}
# {'loss': 0.0247, 'learning_rate': 2.015873015873016e-05, 'epoch': 3.09}
# {'loss': 0.0001, 'learning_rate': 2.0105820105820105e-05, 'epoch': 3.09}
# {'loss': 0.004, 'learning_rate': 2.0052910052910055e-05, 'epoch': 3.1}
# {'loss': 0.0258, 'learning_rate': 2e-05, 'epoch': 3.1}
# {'loss': 0.0001, 'learning_rate': 1.9947089947089948e-05, 'epoch': 3.11}
# {'loss': 0.0001, 'learning_rate': 1.9894179894179895e-05, 'epoch': 3.11}
# {'loss': 0.0237, 'learning_rate': 1.984126984126984e-05, 'epoch': 3.12}
# {'loss': 0.0017, 'learning_rate': 1.9788359788359788e-05, 'epoch': 3.12}
# {'loss': 0.0198, 'learning_rate': 1.9735449735449738e-05, 'epoch': 3.13}
# {'loss': 0.0008, 'learning_rate': 1.9682539682539684e-05, 'epoch': 3.13}
# {'loss': 0.0078, 'learning_rate': 1.962962962962963e-05, 'epoch': 3.14}
# {'loss': 0.0137, 'learning_rate': 1.9576719576719577e-05, 'epoch': 3.14}
# {'loss': 0.0006, 'learning_rate': 1.9523809523809524e-05, 'epoch': 3.15}
# {'loss': 0.0002, 'learning_rate': 1.9470899470899474e-05, 'epoch': 3.15}
# {'loss': 0.0001, 'learning_rate': 1.9417989417989417e-05, 'epoch': 3.16}
# {'loss': 0.0113, 'learning_rate': 1.9365079365079367e-05, 'epoch': 3.16}
# {'loss': 0.0001, 'learning_rate': 1.9312169312169313e-05, 'epoch': 3.17}
# {'loss': 0.0001, 'learning_rate': 1.925925925925926e-05, 'epoch': 3.17}
# {'loss': 0.0002, 'learning_rate': 1.920634920634921e-05, 'epoch': 3.18}
# {'loss': 0.0003, 'learning_rate': 1.9153439153439153e-05, 'epoch': 3.18}
# {'loss': 0.0267, 'learning_rate': 1.9100529100529103e-05, 'epoch': 3.19}
# {'loss': 0.0248, 'learning_rate': 1.9047619047619046e-05, 'epoch': 3.19}
# {'loss': 0.0002, 'learning_rate': 1.8994708994708996e-05, 'epoch': 3.2}
# {'loss': 0.0315, 'learning_rate': 1.8941798941798943e-05, 'epoch': 3.2}
# {'loss': 0.0001, 'learning_rate': 1.888888888888889e-05, 'epoch': 3.21}
# ...
# {'loss': 0.0138, 'learning_rate': 1.126984126984127e-05, 'epoch': 3.93}
# {'loss': 0.0548, 'learning_rate': 1.1216931216931217e-05, 'epoch': 3.93}
# {'loss': 0.0001, 'learning_rate': 1.1164021164021163e-05, 'epoch': 3.94}
# {'loss': 0.0001, 'learning_rate': 1.1111111111111112e-05, 'epoch': 3.94}
# {'loss': 0.0052, 'learning_rate': 1.105820105820106e-05, 'epoch': 3.95}
# {'loss': 0.0001, 'learning_rate': 1.1005291005291006e-05, 'epoch': 3.95}
# {'loss': 0.0392, 'learning_rate': 1.0952380952380953e-05, 'epoch': 3.96}
# {'loss': 0.0006, 'learning_rate': 1.08994708994709e-05, 'epoch': 3.96}
# {'loss': 0.0001, 'learning_rate': 1.0846560846560846e-05, 'epoch': 3.97}
# {'loss': 0.038, 'learning_rate': 1.0793650793650794e-05, 'epoch': 3.97}
# {'loss': 0.0288, 'learning_rate': 1.074074074074074e-05, 'epoch': 3.98}
# {'loss': 0.0014, 'learning_rate': 1.0687830687830689e-05, 'epoch': 3.98}
# {'loss': 0.0003, 'learning_rate': 1.0634920634920636e-05, 'epoch': 3.99}
# {'loss': 0.0104, 'learning_rate': 1.0582010582010582e-05, 'epoch': 3.99}
# {'loss': 0.0598, 'learning_rate': 1.052910052910053e-05, 'epoch': 4.0}
#   0%|          | 0/125 [00:00<?, ?it/s]
# {'eval_loss': 0.07114830613136292, 'eval_accuracy': 0.9876853480774064, 'eval_runtime': 346.1211, 'eval_samples_per_second': 22.992, 'eval_steps_per_second': 0.361, 'epoch': 4.0}
# {'loss': 0.0423, 'learning_rate': 1.0476190476190477e-05, 'epoch': 4.01}
# {'loss': 0.0001, 'learning_rate': 1.0423280423280423e-05, 'epoch': 4.01}
# {'loss': 0.0005, 'learning_rate': 1.037037037037037e-05, 'epoch': 4.02}
# {'loss': 0.0002, 'learning_rate': 1.0317460317460318e-05, 'epoch': 4.02}
# {'loss': 0.0123, 'learning_rate': 1.0264550264550265e-05, 'epoch': 4.03}
# {'loss': 0.0002, 'learning_rate': 1.0211640211640213e-05, 'epoch': 4.03}
# {'loss': 0.0002, 'learning_rate': 1.015873015873016e-05, 'epoch': 4.04}
# {'loss': 0.0001, 'learning_rate': 1.0105820105820106e-05, 'epoch': 4.04}
# {'loss': 0.001, 'learning_rate': 1.0052910052910053e-05, 'epoch': 4.05}
# {'loss': 0.0001, 'learning_rate': 1e-05, 'epoch': 4.05}
# {'loss': 0.0002, 'learning_rate': 9.947089947089947e-06, 'epoch': 4.06}
# {'loss': 0.0001, 'learning_rate': 9.894179894179894e-06, 'epoch': 4.06}
# {'loss': 0.0001, 'learning_rate': 9.841269841269842e-06, 'epoch': 4.07}
# {'loss': 0.0001, 'learning_rate': 9.788359788359789e-06, 'epoch': 4.07}
# {'loss': 0.0001, 'learning_rate': 9.735449735449737e-06, 'epoch': 4.08}
# {'loss': 0.0001, 'learning_rate': 9.682539682539683e-06, 'epoch': 4.08}
# {'loss': 0.0046, 'learning_rate': 9.62962962962963e-06, 'epoch': 4.09}
# {'loss': 0.0305, 'learning_rate': 9.576719576719577e-06, 'epoch': 4.09}
# {'loss': 0.0001, 'learning_rate': 9.523809523809523e-06, 'epoch': 4.1}
# {'loss': 0.0002, 'learning_rate': 9.470899470899471e-06, 'epoch': 4.1}
# {'loss': 0.0001, 'learning_rate': 9.41798941798942e-06, 'epoch': 4.11}
# {'loss': 0.0075, 'learning_rate': 9.365079365079366e-06, 'epoch': 4.11}
# {'loss': 0.0049, 'learning_rate': 9.312169312169313e-06, 'epoch': 4.12}
# {'loss': 0.0006, 'learning_rate': 9.259259259259259e-06, 'epoch': 4.12}
# {'loss': 0.0001, 'learning_rate': 9.206349206349207e-06, 'epoch': 4.13}
# {'loss': 0.0001, 'learning_rate': 9.153439153439154e-06, 'epoch': 4.13}
# {'loss': 0.0001, 'learning_rate': 9.1005291005291e-06, 'epoch': 4.14}
# {'loss': 0.0001, 'learning_rate': 9.047619047619047e-06, 'epoch': 4.14}
# {'loss': 0.0002, 'learning_rate': 8.994708994708995e-06, 'epoch': 4.15}
# {'loss': 0.0001, 'learning_rate': 8.941798941798943e-06, 'epoch': 4.15}
# {'loss': 0.0001, 'learning_rate': 8.88888888888889e-06, 'epoch': 4.16}
# {'loss': 0.0001, 'learning_rate': 8.835978835978837e-06, 'epoch': 4.16}
# {'loss': 0.0284, 'learning_rate': 8.783068783068783e-06, 'epoch': 4.17}
# {'loss': 0.0, 'learning_rate': 8.73015873015873e-06, 'epoch': 4.17}
# {'loss': 0.0046, 'learning_rate': 8.677248677248678e-06, 'epoch': 4.18}
# {'loss': 0.0003, 'learning_rate': 8.624338624338624e-06, 'epoch': 4.18}
# {'loss': 0.0008, 'learning_rate': 8.571428571428573e-06, 'epoch': 4.19}
# {'loss': 0.0001, 'learning_rate': 8.518518518518519e-06, 'epoch': 4.19}
# {'loss': 0.0232, 'learning_rate': 8.465608465608466e-06, 'epoch': 4.2}
# {'loss': 0.0003, 'learning_rate': 8.412698412698414e-06, 'epoch': 4.2}
# {'loss': 0.0123, 'learning_rate': 8.35978835978836e-06, 'epoch': 4.21}
# {'loss': 0.0002, 'learning_rate': 8.306878306878307e-06, 'epoch': 4.21}
# {'loss': 0.0002, 'learning_rate': 8.253968253968254e-06, 'epoch': 4.22}
# {'loss': 0.0027, 'learning_rate': 8.201058201058202e-06, 'epoch': 4.22}
# {'loss': 0.0044, 'learning_rate': 8.14814814814815e-06, 'epoch': 4.23}
# {'loss': 0.0002, 'learning_rate': 8.095238095238097e-06, 'epoch': 4.23}
# {'loss': 0.0001, 'learning_rate': 8.042328042328043e-06, 'epoch': 4.24}
# {'loss': 0.0001, 'learning_rate': 7.98941798941799e-06, 'epoch': 4.24}
# {'loss': 0.0008, 'learning_rate': 7.936507936507936e-06, 'epoch': 4.25}
# {'loss': 0.0001, 'learning_rate': 7.883597883597884e-06, 'epoch': 4.25}
# {'loss': 0.0002, 'learning_rate': 7.830687830687831e-06, 'epoch': 4.26}
# {'loss': 0.002, 'learning_rate': 7.777777777777777e-06, 'epoch': 4.26}
# {'loss': 0.0001, 'learning_rate': 7.724867724867726e-06, 'epoch': 4.27}
# {'loss': 0.0001, 'learning_rate': 7.671957671957672e-06, 'epoch': 4.27}
# {'loss': 0.0004, 'learning_rate': 7.6190476190476205e-06, 'epoch': 4.28}
# {'loss': 0.0001, 'learning_rate': 7.566137566137567e-06, 'epoch': 4.28}
# {'loss': 0.0001, 'learning_rate': 7.5132275132275136e-06, 'epoch': 4.29}
# {'loss': 0.0001, 'learning_rate': 7.460317460317461e-06, 'epoch': 4.29}
# {'loss': 0.0001, 'learning_rate': 7.4074074074074075e-06, 'epoch': 4.3}
# {'loss': 0.0004, 'learning_rate': 7.354497354497354e-06, 'epoch': 4.3}
# {'loss': 0.0001, 'learning_rate': 7.301587301587302e-06, 'epoch': 4.31}
# {'loss': 0.0001, 'learning_rate': 7.248677248677249e-06, 'epoch': 4.31}
# {'loss': 0.0002, 'learning_rate': 7.195767195767196e-06, 'epoch': 4.32}
# {'loss': 0.0001, 'learning_rate': 7.142857142857143e-06, 'epoch': 4.32}
# {'loss': 0.0001, 'learning_rate': 7.089947089947089e-06, 'epoch': 4.33}
# {'loss': 0.0001, 'learning_rate': 7.0370370370370375e-06, 'epoch': 4.33}
# {'loss': 0.0001, 'learning_rate': 6.984126984126985e-06, 'epoch': 4.34}
# {'loss': 0.0579, 'learning_rate': 6.931216931216931e-06, 'epoch': 4.34}
# {'loss': 0.0445, 'learning_rate': 6.878306878306878e-06, 'epoch': 4.35}
# {'loss': 0.0, 'learning_rate': 6.825396825396825e-06, 'epoch': 4.35}
# {'loss': 0.0001, 'learning_rate': 6.7724867724867736e-06, 'epoch': 4.36}
# {'loss': 0.0001, 'learning_rate': 6.71957671957672e-06, 'epoch': 4.36}
# {'loss': 0.0001, 'learning_rate': 6.666666666666667e-06, 'epoch': 4.37}
# {'loss': 0.0001, 'learning_rate': 6.613756613756614e-06, 'epoch': 4.37}
# {'loss': 0.0002, 'learning_rate': 6.5608465608465606e-06, 'epoch': 4.38}
# {'loss': 0.0001, 'learning_rate': 6.507936507936509e-06, 'epoch': 4.38}
# {'loss': 0.0001, 'learning_rate': 6.455026455026455e-06, 'epoch': 4.39}
# {'loss': 0.0366, 'learning_rate': 6.402116402116403e-06, 'epoch': 4.39}
# {'loss': 0.0007, 'learning_rate': 6.349206349206349e-06, 'epoch': 4.4}
# {'loss': 0.0004, 'learning_rate': 6.296296296296296e-06, 'epoch': 4.4}
# {'loss': 0.0002, 'learning_rate': 6.243386243386243e-06, 'epoch': 4.41}
# {'loss': 0.0001, 'learning_rate': 6.190476190476191e-06, 'epoch': 4.41}
# {'loss': 0.0003, 'learning_rate': 6.137566137566138e-06, 'epoch': 4.42}
# {'loss': 0.0, 'learning_rate': 6.0846560846560845e-06, 'epoch': 4.42}
# {'loss': 0.0001, 'learning_rate': 6.031746031746032e-06, 'epoch': 4.43}
# {'loss': 0.0001, 'learning_rate': 5.978835978835979e-06, 'epoch': 4.43}
# {'loss': 0.0001, 'learning_rate': 5.925925925925927e-06, 'epoch': 4.44}
# {'loss': 0.0001, 'learning_rate': 5.873015873015873e-06, 'epoch': 4.44}
# {'loss': 0.0, 'learning_rate': 5.82010582010582e-06, 'epoch': 4.45}
# {'loss': 0.0001, 'learning_rate': 5.767195767195768e-06, 'epoch': 4.45}
# {'loss': 0.0, 'learning_rate': 5.7142857142857145e-06, 'epoch': 4.46}
# {'loss': 0.0001, 'learning_rate': 5.661375661375662e-06, 'epoch': 4.46}
# {'loss': 0.0, 'learning_rate': 5.6084656084656084e-06, 'epoch': 4.47}
# {'loss': 0.0001, 'learning_rate': 5.555555555555556e-06, 'epoch': 4.47}
# {'loss': 0.0, 'learning_rate': 5.502645502645503e-06, 'epoch': 4.48}
# {'loss': 0.0004, 'learning_rate': 5.44973544973545e-06, 'epoch': 4.48}
# {'loss': 0.0, 'learning_rate': 5.396825396825397e-06, 'epoch': 4.49}
# {'loss': 0.0001, 'learning_rate': 5.3439153439153445e-06, 'epoch': 4.49}
# {'loss': 0.0001, 'learning_rate': 5.291005291005291e-06, 'epoch': 4.5}
# {'loss': 0.0001, 'learning_rate': 5.2380952380952384e-06, 'epoch': 4.5}
# {'loss': 0.0001, 'learning_rate': 5.185185185185185e-06, 'epoch': 4.51}
# {'loss': 0.036, 'learning_rate': 5.132275132275132e-06, 'epoch': 4.51}
# {'loss': 0.0001, 'learning_rate': 5.07936507936508e-06, 'epoch': 4.52}
# {'loss': 0.0001, 'learning_rate': 5.026455026455026e-06, 'epoch': 4.52}
# {'loss': 0.0, 'learning_rate': 4.973544973544974e-06, 'epoch': 4.53}
# {'loss': 0.0001, 'learning_rate': 4.920634920634921e-06, 'epoch': 4.53}
# {'loss': 0.0001, 'learning_rate': 4.8677248677248685e-06, 'epoch': 4.54}
# {'loss': 0.0, 'learning_rate': 4.814814814814815e-06, 'epoch': 4.54}
# {'loss': 0.0001, 'learning_rate': 4.7619047619047615e-06, 'epoch': 4.55}
# {'loss': 0.0083, 'learning_rate': 4.70899470899471e-06, 'epoch': 4.55}
# {'loss': 0.0, 'learning_rate': 4.656084656084656e-06, 'epoch': 4.56}
# {'loss': 0.0056, 'learning_rate': 4.603174603174604e-06, 'epoch': 4.56}
# {'loss': 0.0001, 'learning_rate': 4.55026455026455e-06, 'epoch': 4.57}
# {'loss': 0.0021, 'learning_rate': 4.497354497354498e-06, 'epoch': 4.57}
# {'loss': 0.0002, 'learning_rate': 4.444444444444445e-06, 'epoch': 4.58}
# {'loss': 0.0002, 'learning_rate': 4.3915343915343915e-06, 'epoch': 4.58}
# {'loss': 0.0, 'learning_rate': 4.338624338624339e-06, 'epoch': 4.59}
# {'loss': 0.0001, 'learning_rate': 4.285714285714286e-06, 'epoch': 4.59}
# {'loss': 0.0001, 'learning_rate': 4.232804232804233e-06, 'epoch': 4.6}
# {'loss': 0.0, 'learning_rate': 4.17989417989418e-06, 'epoch': 4.6}
# {'loss': 0.0001, 'learning_rate': 4.126984126984127e-06, 'epoch': 4.61}
# {'loss': 0.0001, 'learning_rate': 4.074074074074075e-06, 'epoch': 4.61}
# {'loss': 0.0001, 'learning_rate': 4.0211640211640215e-06, 'epoch': 4.62}
# {'loss': 0.0002, 'learning_rate': 3.968253968253968e-06, 'epoch': 4.62}
# {'loss': 0.0, 'learning_rate': 3.9153439153439155e-06, 'epoch': 4.63}
# {'loss': 0.0, 'learning_rate': 3.862433862433863e-06, 'epoch': 4.63}
# {'loss': 0.0, 'learning_rate': 3.8095238095238102e-06, 'epoch': 4.64}
# {'loss': 0.0001, 'learning_rate': 3.7566137566137568e-06, 'epoch': 4.64}
# {'loss': 0.0, 'learning_rate': 3.7037037037037037e-06, 'epoch': 4.65}
# {'loss': 0.0, 'learning_rate': 3.650793650793651e-06, 'epoch': 4.65}
# {'loss': 0.0002, 'learning_rate': 3.597883597883598e-06, 'epoch': 4.66}
# {'loss': 0.0, 'learning_rate': 3.5449735449735446e-06, 'epoch': 4.66}
# {'loss': 0.0001, 'learning_rate': 3.4920634920634924e-06, 'epoch': 4.67}
# {'loss': 0.0001, 'learning_rate': 3.439153439153439e-06, 'epoch': 4.67}
# {'loss': 0.0004, 'learning_rate': 3.3862433862433868e-06, 'epoch': 4.68}
# {'loss': 0.0, 'learning_rate': 3.3333333333333333e-06, 'epoch': 4.68}
# {'loss': 0.0, 'learning_rate': 3.2804232804232803e-06, 'epoch': 4.69}
# {'loss': 0.0, 'learning_rate': 3.2275132275132277e-06, 'epoch': 4.69}
# {'loss': 0.0001, 'learning_rate': 3.1746031746031746e-06, 'epoch': 4.7}
# {'loss': 0.0001, 'learning_rate': 3.1216931216931216e-06, 'epoch': 4.7}
# {'loss': 0.0006, 'learning_rate': 3.068783068783069e-06, 'epoch': 4.71}
# {'loss': 0.0001, 'learning_rate': 3.015873015873016e-06, 'epoch': 4.71}
# {'loss': 0.0, 'learning_rate': 2.9629629629629633e-06, 'epoch': 4.72}
# {'loss': 0.0, 'learning_rate': 2.91005291005291e-06, 'epoch': 4.72}
# {'loss': 0.0003, 'learning_rate': 2.8571428571428573e-06, 'epoch': 4.73}
# {'loss': 0.0001, 'learning_rate': 2.8042328042328042e-06, 'epoch': 4.73}
# {'loss': 0.0029, 'learning_rate': 2.7513227513227516e-06, 'epoch': 4.74}
# {'loss': 0.0001, 'learning_rate': 2.6984126984126986e-06, 'epoch': 4.74}
# {'loss': 0.0001, 'learning_rate': 2.6455026455026455e-06, 'epoch': 4.75}
# {'loss': 0.0012, 'learning_rate': 2.5925925925925925e-06, 'epoch': 4.75}
# {'loss': 0.0319, 'learning_rate': 2.53968253968254e-06, 'epoch': 4.76}
# {'loss': 0.0, 'learning_rate': 2.486772486772487e-06, 'epoch': 4.76}
# {'loss': 0.0001, 'learning_rate': 2.4338624338624342e-06, 'epoch': 4.77}
# {'loss': 0.0001, 'learning_rate': 2.3809523809523808e-06, 'epoch': 4.77}
# {'loss': 0.0, 'learning_rate': 2.328042328042328e-06, 'epoch': 4.78}
# {'loss': 0.0025, 'learning_rate': 2.275132275132275e-06, 'epoch': 4.78}
# {'loss': 0.015, 'learning_rate': 2.2222222222222225e-06, 'epoch': 4.79}
# {'loss': 0.0, 'learning_rate': 2.1693121693121695e-06, 'epoch': 4.79}
# {'loss': 0.0, 'learning_rate': 2.1164021164021164e-06, 'epoch': 4.8}
# {'loss': 0.0001, 'learning_rate': 2.0634920634920634e-06, 'epoch': 4.8}
# {'loss': 0.0001, 'learning_rate': 2.0105820105820108e-06, 'epoch': 4.81}
# {'loss': 0.0044, 'learning_rate': 1.9576719576719577e-06, 'epoch': 4.81}
# {'loss': 0.0, 'learning_rate': 1.9047619047619051e-06, 'epoch': 4.82}
# {'loss': 0.0002, 'learning_rate': 1.8518518518518519e-06, 'epoch': 4.82}
# {'loss': 0.0, 'learning_rate': 1.798941798941799e-06, 'epoch': 4.83}
# {'loss': 0.0002, 'learning_rate': 1.7460317460317462e-06, 'epoch': 4.83}
# {'loss': 0.0, 'learning_rate': 1.6931216931216934e-06, 'epoch': 4.84}
# {'loss': 0.0, 'learning_rate': 1.6402116402116401e-06, 'epoch': 4.84}
# {'loss': 0.0338, 'learning_rate': 1.5873015873015873e-06, 'epoch': 4.85}
# {'loss': 0.0036, 'learning_rate': 1.5343915343915345e-06, 'epoch': 4.85}
# {'loss': 0.0002, 'learning_rate': 1.4814814814814817e-06, 'epoch': 4.86}
# {'loss': 0.0001, 'learning_rate': 1.4285714285714286e-06, 'epoch': 4.86}
# {'loss': 0.0001, 'learning_rate': 1.3756613756613758e-06, 'epoch': 4.87}
# {'loss': 0.0, 'learning_rate': 1.3227513227513228e-06, 'epoch': 4.87}
# {'loss': 0.0001, 'learning_rate': 1.26984126984127e-06, 'epoch': 4.88}
# {'loss': 0.0, 'learning_rate': 1.2169312169312171e-06, 'epoch': 4.88}
# {'loss': 0.0, 'learning_rate': 1.164021164021164e-06, 'epoch': 4.89}
# {'loss': 0.0095, 'learning_rate': 1.1111111111111112e-06, 'epoch': 4.89}
# {'loss': 0.0, 'learning_rate': 1.0582010582010582e-06, 'epoch': 4.9}
# {'loss': 0.0, 'learning_rate': 1.0052910052910054e-06, 'epoch': 4.9}
# {'loss': 0.0003, 'learning_rate': 9.523809523809526e-07, 'epoch': 4.91}
# {'loss': 0.0, 'learning_rate': 8.994708994708995e-07, 'epoch': 4.91}
# {'loss': 0.0001, 'learning_rate': 8.465608465608467e-07, 'epoch': 4.92}
# {'loss': 0.0, 'learning_rate': 7.936507936507937e-07, 'epoch': 4.92}
# {'loss': 0.0478, 'learning_rate': 7.407407407407408e-07, 'epoch': 4.93}
# {'loss': 0.0, 'learning_rate': 6.878306878306879e-07, 'epoch': 4.93}
# {'loss': 0.0001, 'learning_rate': 6.34920634920635e-07, 'epoch': 4.94}
# {'loss': 0.0001, 'learning_rate': 5.82010582010582e-07, 'epoch': 4.94}
# {'loss': 0.0005, 'learning_rate': 5.291005291005291e-07, 'epoch': 4.95}
# {'loss': 0.0072, 'learning_rate': 4.761904761904763e-07, 'epoch': 4.95}
# {'loss': 0.0, 'learning_rate': 4.2328042328042335e-07, 'epoch': 4.96}
# {'loss': 0.0055, 'learning_rate': 3.703703703703704e-07, 'epoch': 4.96}
# {'loss': 0.0001, 'learning_rate': 3.174603174603175e-07, 'epoch': 4.97}
# {'loss': 0.0001, 'learning_rate': 2.6455026455026455e-07, 'epoch': 4.97}
# {'loss': 0.0476, 'learning_rate': 2.1164021164021167e-07, 'epoch': 4.98}
# {'loss': 0.0001, 'learning_rate': 1.5873015873015874e-07, 'epoch': 4.98}
# {'loss': 0.0001, 'learning_rate': 1.0582010582010584e-07, 'epoch': 4.99}
# {'loss': 0.0001, 'learning_rate': 5.291005291005292e-08, 'epoch': 4.99}
# {'loss': 0.066, 'learning_rate': 0.0, 'epoch': 5.0}
#   0%|          | 0/125 [00:00<?, ?it/s]
# {'eval_loss': 0.08163642883300781, 'eval_accuracy': 0.9876853480774064, 'eval_runtime': 347.1038, 'eval_samples_per_second': 22.927, 'eval_steps_per_second': 0.36, 'epoch': 5.0}
# {'train_runtime': 29882.1646, 'train_samples_per_second': 5.326, 'train_steps_per_second': 0.333, 'train_loss': 0.05499702816711208, 'epoch': 5.0}
#   0%|          | 0/125 [00:00<?, ?it/s]
# Test Loss: 0.08163642883300781, Test Accuracy: 0.9876853480774064

# %%
len(df)
# Out:
# 39788

# %%
model.save_pretrained('./distilbert-drug-review-model')
tokenizer.save_pretrained('./distilbert-drug-review-tokenizer')
# Out:
# ('./distilbert-drug-review-tokenizer/tokenizer_config.json',
#  './distilbert-drug-review-tokenizer/special_tokens_map.json',
#  './distilbert-drug-review-tokenizer/vocab.txt',
#  './distilbert-drug-review-tokenizer/added_tokens.json')

# %%
print("Model directory contents:", os.listdir('./distilbert-drug-review-model'))
print("Tokenizer directory contents:", os.listdir('./distilbert-drug-review-tokenizer'))
# Out:
# Model directory contents: ['config.json', 'pytorch_model.bin']
# Tokenizer directory contents: ['tokenizer_config.json', 'special_tokens_map.json', 'vocab.txt']

# %%
# Load trained model and tokenizer
model_path = './distilbert-drug-review-model'
tokenizer_path = './distilbert-drug-review-tokenizer'

model = DistilBertForSequenceClassification.from_pretrained(model_path)
tokenizer = DistilBertTokenizer.from_pretrained(tokenizer_path)

# %%
def predict_condition(texts):
    encoded_texts = tokenizer(texts, padding=True, truncation=True, max_length=256, return_tensors="pt")
    outputs = model(**encoded_texts)
    predictions = torch.argmax(outputs.logits, dim=-1)
    return [label_encoder.classes_[pred] for pred in predictions.tolist()]  # Adjusted for direct use of classes

# Example usage
texts = [
    "I've been on birth control for two years with no side effects.",
    "This medication made my depression worse.",
    "Excellent control of blood pressure with this medication."
]
predicted_conditions = predict_condition(texts)
for text, pred in zip(texts, predicted_conditions):
    print(f"Text: {text}\nPredicted Condition: {pred}\n")
# Out:
# Text: I've been on birth control for two years with no side effects.
# Predicted Condition: Birth Control
#
# Text: This medication made my depression worse.
# Predicted Condition: Depression
#
# Text: Excellent control of blood pressure with this medication.
# Predicted Condition: High Blood Pressure

# %%
joblib.dump(label_encoder, 'label_encoder.pkl')  # Saving
label_encoder = joblib.load('label_encoder.pkl')  # Loading

# %%
# Out:
# []
